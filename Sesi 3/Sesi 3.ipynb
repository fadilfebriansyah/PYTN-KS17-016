# %%
def changeme(mylist):
    "This changes a passed list into this function"
    mylist.append([1,2,3,4]);
    print("Values inside the function: ",mylist)
    return

mylist = [10,20,30];
changeme(mylist);

# %%
pip --version
# Out:
# pip 22.0.4 from C:\Users\62857\AppData\Local\Programs\Python\Python39\lib\site-packages\pip (python 3.9)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.4.0
# altair                       4.2.2
# amqp                         5.1.1
# anyio                        3.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# asyncio                      3.4.3
# attrs                        22.1.0
# autopep8                     2.0.1
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# billiard                     3.6.4.0
# bleach                       5.0.1
# blinker                      1.5
# cachetools                   5.3.0
# celery                       5.2.7
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# click                        8.1.3
# click-didyoumean             0.3.0
# click-plugins                1.1.1
# click-repl                   0.2.0
# colorama                     0.4.6
# comm                         0.1.2
# contourpy                    1.0.6
# coroutines                   0.1.4
# cycler                       0.11.0
# debugpy                      1.6.4
# decorator                    5.1.1
# defusedxml                   0.7.1
# distlib                      0.3.6
# entrypoints                  0.4
# et-xmlfile                   1.1.0
# executing                    1.2.0
# fastjsonschema               2.16.2
# filelock                     3.8.2
# Flask                        2.2.3
# flatbuffers                  23.1.21
# fonttools                    4.38.0
# fqdn                         1.5.1
# gast                         0.4.0
# gitdb                        4.0.10
# GitPython                    3.1.31
# google-auth                  2.16.1
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.51.3
# h5py                         3.8.0
# idna                         3.4
# importlib-metadata           5.1.0
# ipykernel                    6.19.2
# ipython                      8.7.0
# ipython-genutils             0.2.0
# isoduration                  20.11.0
# itsdangerous                 2.1.2
# jedi                         0.18.2
# Jinja2                       3.1.2
# joblib                       1.2.0
# json5                        0.9.10
# jsonpointer                  2.3
# jsonschema                   4.17.3
# jupyter_client               7.4.8
# jupyter_core                 5.1.0
# jupyter-events               0.5.0
# jupyter_server               2.0.1
# jupyter_server_terminals     0.4.2
# jupyterlab                   3.5.1
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.16.5
# keras                        2.11.0
# kiwisolver                   1.4.4
# kombu                        5.2.4
# libclang                     15.0.6.1
# Markdown                     3.4.1
# markdown-it-py               2.2.0
# MarkupSafe                   2.1.1
# matplotlib                   3.6.2
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# mistune                      2.0.4
# mpi4py                       3.1.4
# nbclassic                    0.4.8
# nbclient                     0.7.2
# nbconvert                    7.2.6
# nbformat                     5.7.0
# nest-asyncio                 1.5.6
# notebook                     6.5.2
# notebook_shim                0.2.2
# ntplib                       0.4.0
# numpy                        1.23.5
# oauthlib                     3.2.2
# openpyxl                     3.1.2
# opt-einsum                   3.3.0
# packaging                    22.0
# pandas                       1.5.2
# pandocfilters                1.5.0
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.3.0
# pip                          22.0.4
# platformdirs                 2.6.0
# prometheus-client            0.15.0
# prompt-toolkit               3.0.36
# protobuf                     3.20.3
# psutil                       5.9.4
# pure-eval                    0.2.2
# pyarrow                      11.0.0
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycodestyle                  2.10.0
# pycparser                    2.21
# pydeck                       0.8.0
# Pygments                     2.14.0
# Pympler                      1.0.1
# pyparsing                    3.0.9
# Pyro4                        4.82
# pyrsistent                   0.19.2
# python-dateutil              2.8.2
# python-json-logger           2.0.4
# pytz                         2022.6
# pytz-deprecation-shim        0.1.0.post0
# pywin32                      305
# pywinpty                     2.0.9
# PyYAML                       6.0
# pyzmq                        24.0.1
# requests                     2.28.1
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         13.3.1
# rsa                          4.9
# scikit-learn                 1.2.0
# scipy                        1.9.3
# seaborn                      0.12.1
# semver                       2.13.0
# Send2Trash                   1.8.0
# serpent                      1.41
# setuptools                   58.1.0
# six                          1.16.0
# sklearn                      0.0.post1
# smmap                        5.0.0
# sniffio                      1.3.0
# sockets                      1.0.0
# soupsieve                    2.3.2.post1
# stack-data                   0.6.2
# streamlit                    1.19.0
# tenacity                     8.2.2
# tensorboard                  2.11.2
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.11.0
# tensorflow-estimator         2.11.0
# tensorflow-intel             2.11.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.2.0
# terminado                    0.17.1
# threadpoolctl                3.1.0
# tinycss2                     1.2.1
# toml                         0.10.2
# tomli                        2.0.1
# toolz                        0.12.0
# tornado                      6.2
# traitlets                    5.7.1
# typing_extensions            4.5.0
# tzdata                       2022.7
# tzlocal                      4.2
# uri-template                 1.2.0
# urllib3                      1.26.13
# validators                   0.20.0
# vine                         5.0.0
# virtualenv                   20.17.1
# watchdog                     2.3.0
# wcwidth                      0.2.5
# webcolors                    1.12
# webencodings                 0.5.1
# websocket-client             1.4.2
# Werkzeug                     2.2.3
# wheel                        0.38.4
# wordcloud                    1.8.2.2
# wrapt                        1.15.0
# xlrd                         2.0.1
# zipp                         3.11.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\62857\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\62857\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\62857\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\62857\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Users\62857\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
